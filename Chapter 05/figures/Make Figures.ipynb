# %%
from draw3d import *

# %%
draw3d(
    Arrow3D((1,0,0),color='C0'),
    Segment3D((1,0,0),(0,0,0),color='C0'),
    Arrow3D((0,1,0),color='C2'),
    Segment3D((0,1,0),(0,0,0),color='C2'),
    Arrow3D((0,0,1),color='C3'),
    Segment3D((0,0,1),(0,0,0),color='C3'),
    Points3D((2,1,1),(1,2,1),(1,1,2),color=(0,0,0,0)),
    save_as='EXERCISE_section_5.1.6_left.svg'
)

# %%
draw3d(
    Arrow3D((2,1,1),color='C0'),
    Arrow3D((1,2,1),color='C2'),
    Arrow3D((1,1,2),color='C3'),
    save_as='EXERCISE_section_5.1.6_right.svg'
)

# %%
from vector_drawing import *

dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4),
    (-5,3), (-5,2), (-2,2), (-5,1), (-4,0), (-2,1), (-1,0), (0,-3),
    (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)
]

draw(
    Points(*dino_vectors),
    Polygon(*dino_vectors),
    save_as='5.24.svg'
)

# %%
from draw3d import *

def polygon_segments_3d(points,color='C0'):
    count = len(points)
    return [Segment3D(points[i], points[(i+1) % count],color=color) for i in range(0,count)]

dino_3d = [(x,y,1) for x,y in dino_vectors]

draw3d(
    Points3D(*dino_3d, color='C0'),
    *polygon_segments_3d(dino_3d),
    save_as='5.25.svg'
)

# %%
draw3d(
    Arrow3D((1,0,0),color='C0'),
    Segment3D((1,0,0),(0,0,0),color='C0'),
    Arrow3D((0,1,0),color='C0'),
    Segment3D((0,1,0),(0,0,0),color='C0'),
    Arrow3D((0,0,1),color='C0'),
    Segment3D((0,0,1),(0,0,0),color='C0'),
    Arrow3D((3,1,1),color='C0'),
    Box3D(3,1,1),
    save_as='5.29.svg'
)

# %%
draw3d(
    Points3D((-3,-3,-3),(3,3,3),color=(0,0,0,0)),
    axes=False,
    origin=False,
    save_as='5.33.svg'
)

# %%
draw3d(
    Points3D((-3,-3,-3),(3,3,3),color=(0,0,0,0)),
    axes=False,
    origin=False,
    save_as='5.34abcde.svg'
)
