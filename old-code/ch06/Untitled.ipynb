# %%
from math import sqrt, pi
import matplotlib
from vectors import *
from vector_drawing import *
import os
from matplotlib.patches import Polygon, FancyArrowPatch
from matplotlib.collections import PatchCollection
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D, proj3d
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import numpy as np

# %%
plane = Plane((-1,-1),(5,5),"2d-vector-addition")
v = (4,3)
w = (-2,1)
o = (0,0)
plane.draw_arrow(o,v,color='r')
plane.draw_arrow(v,add(v,w),color='b')
plane.draw_arrow(o,add(v,w),color='k')
plane.draw_axes()

# %%
space = Space((-1,-1,-1),(5,5,5), "3d-vector-addition")
o = (0,0,0)
v1 = (3,3,4)
v2 = (0,2,-2)
space.draw_axes()
space.draw_arrow(o,v1)
space.draw_arrow(v1,add(v1,v2))
space.draw_arrow(o,add(v1,v2))
