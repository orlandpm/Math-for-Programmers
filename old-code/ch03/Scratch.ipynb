# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from draw3d import *

draw3d(
    Points3D((1,1,1), (0,0,1)), 
    Segment3D((1,1,1), (0,0,1)), 
    Arrow3D((1,1,1), (1,0,0)),
    Polygon3D((0,0,0), (1,0,0), (1,0,1), color=green),
    Box3D(1,1,1),
    origin=True)
