# %%
import requests
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# %%
def try_float_prop(x, c):
    try:
        y = float(x.find('span',class_=c).text)
    except:
        y = None
    return y

from datetime import datetime, timedelta
day = timedelta(days=1)

def posted(x):
    try:
        y = x.find('span',class_='pt').text
        d = datetime.strptime(y,"%m/%d - %H:%M")
        d = d.replace(year=2019)
        y = ((datetime.now() - d) / day)
    except:
        y = None
    return y

def get_cars(make,model,yr):
    url = "https://cargraph.com/usa/{}/{}/{}".format(make,model,yr)
    print(url)
    r = requests.get("https://cargraph.com/usa/{}/{}/{}".format(make,model,yr))
    soup = BeautifulSoup(r.content)

    cars = []
    for x in soup.find_all('div', class_='row'):
        year = try_float_prop(x,'y')
        miles = try_float_prop(x,'mi')
        price = try_float_prop(x,'p')
        pt = posted(x)
        cars.append((make,model,year,miles,price,pt))

    return [car for car in cars if all(car)]

def get_cars_years(make,model,years):
    return set([car for car in get_cars(make,model,year) for year in years])

# %%
# get_cars_years("toyota", "prius", range(2012,2020))

# %%
# get_cars("toyota","prius",2012) + get_cars("toyota","prius",2013)

# %%
# list(range(2012,2020))

# %%
# priuses = [car for yr in range(2001,2021) for car in get_cars("toyota","prius",yr)]
# priuses = set(priuses)

# %%
priuses = {('toyota', 'prius', 2001.0, 40.0, 1999.0, 89.53669775157407),
 ('toyota', 'prius', 2001.0, 40.0, 1999.0, 92.31864219824074),
 ('toyota', 'prius', 2001.0, 40.0, 2199.0, 95.71655886936342),
 ('toyota', 'prius', 2001.0, 40.0, 2199.0, 97.19503110253473),
 ('toyota', 'prius', 2001.0, 40.0, 2400.0, 102.53253111582175),
 ('toyota', 'prius', 2001.0, 40.0, 2400.0, 104.67419778694445),
 ('toyota', 'prius', 2001.0, 126.0, 4495.0, 0.2762809419791667),
 ('toyota', 'prius', 2001.0, 126.0, 4495.0, 0.27637631777777777),
 ('toyota', 'prius', 2001.0, 250.0, 4990.0, 4.834614272974537),
 ('toyota', 'prius', 2001.0, 59000.0, 2600.0, 8.163780977789353),
 ('toyota', 'prius', 2001.0, 79159.0, 5499.0, 30.97905873259259),
 ('toyota', 'prius', 2001.0, 90805.0, 2999.0, -11.200107826018519),
 ('toyota', 'prius', 2001.0, 96000.0, 3995.0, 159.76794768059028),
 ('toyota', 'prius', 2001.0, 96749.0, 2900.0, 167.7436421294676),
 ('toyota', 'prius', 2001.0, 96952.0, 5999.0, 88.40128098215278),
 ('toyota', 'prius', 2001.0, 100000.0, 4599.0, 36.46100319048611),
 ('toyota', 'prius', 2001.0, 100000.0, 4599.0, 73.96794764224538),
 ('toyota', 'prius', 2001.0, 104142.0, 3995.0, 107.85822543628473),
 ('toyota', 'prius', 2001.0, 119860.0, 2998.0, 209.94503103155094),
 ('toyota', 'prius', 2001.0, 120000.0, 1250.0, 54.32697549592593),
 ('toyota', 'prius', 2001.0, 121000.0, 3000.0, 10.542253220717592),
 ('toyota', 'prius', 2001.0, 121000.0, 3495.0, 108.00822544512731),
 ('toyota', 'prius', 2001.0, 133000.0, 2000.0, 170.7353088005324),
 ('toyota', 'prius', 2001.0, 134143.0, 1995.0, 223.7366977026273),
 ('toyota', 'prius', 2018.0, 32666.0, 19995.0, -0.12224622032407408),
 ('toyota', 'prius', 2018.0, 100000.0, 22481.0, -0.08057958193287038),
 ('toyota', 'prius', 2019.0, 63.0, 26975.0, 165.75900971607638),
 ('toyota', 'prius', 2019.0, 695.0, 26750.0, -0.14724029496527777),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.847204180046296),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.8478986339699075),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.847898640775463),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.8478986454976853),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.8478986502314814),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.847898654583333),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.8888708424189815),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.888870844560185),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.889565295451389),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.889565297604167),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.8895653099421295),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.889565314351852),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.8895653190856483),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.9312319945023146),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.9722041821875),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.972898637615741),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.9728986567824074),
 ('toyota', 'prius', 2019.0, 2420.0, 26460.0, 2.972898658946759),
 ('toyota', 'prius', 2019.0, 3000.0, 32435.0, 2.8472041736111113),
 ('toyota', 'prius', 2019.0, 3227.0, 20498.0, 0.8548430515856481),
 ('toyota', 'prius', 2019.0, 3647.0, 26990.0, 2.8333152825462964),
 ('toyota', 'prius', 2019.0, 8343.0, 27995.0, 1.837481944837963),
 ('toyota', 'prius', 2019.0, 14129.0, 22000.0, 0.845120825),
 ('toyota', 'prius', 2019.0, 100000.0, 26188.0, -0.0021014016203703702)}

# %%
prius_mileage_price = [(p[3],p[4]) for p in priuses]

# %%
plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.5)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)
# Out:
# Text(0.5,0,'Odometer (mi)')

# %%
plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.5)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)

plt.plot([0,350000],[20000, 20000-0.05*350000],c='k')

# %%
len([p for p in priuses if p[3] > 500])
# Out:
# 737

# %%
import numpy as np
from numpy import log, exp
from scipy import stats

a = np.array(list([p for p in priuses if p[3]]))
mileage = a[:,3].astype('float')
price = a[:,4].astype('float')

bestfit = stats.linregress(mileage,price)
f = lambda x : bestfit.slope * x + bestfit.intercept
# # f = lambda x : 26500 * exp(-9.953e-06 * x)
# # (bestfit.slope, exp(bestfit.intercept))

# %%
# plt.scatter(mileage,price,alpha=0.5)

plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.3)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)


# plt.plot(range(0,350000,5000),[f(x) for x in range(0,350000,5000)],c='k')
plt.ylim(0,37000)
# Out:
# (0, 37000)

# %%
[(x/10.0, 2*x/10.0 + np.random.normal(0,0.3)) for x in range(-10,11)]
# Out:
# [(-1.0, -1.931991594367695),
#  (-0.9, -1.4067270036766688),
#  (-0.8, -1.2005590152997467),
#  (-0.7, -1.6860591637156295),
#  (-0.6, -1.212427044102794),
#  (-0.5, -0.9603579138053066),
#  (-0.4, -0.5296220476752146),
#  (-0.3, -0.5792400881498934),
#  (-0.2, -0.289888013860396),
#  (-0.1, -0.5225401081271543),
#  (0.0, 0.09269763490789935),
#  (0.1, 0.07540983771904314),
#  (0.2, 0.2823495751604905),
#  (0.3, 0.5758244866418833),
#  (0.4, 0.30388670661625106),
#  (0.5, 1.003349514533686),
#  (0.6, 1.5096714648253422),
#  (0.7, 1.8398918314444206),
#  (0.8, 1.3571997951976233),
#  (0.9, 1.338291540200084),
#  (1.0, 1.9902578841532454)]

# %%
test_data = [(-1.0, -2.0137862606487387),
 (-0.9, -1.7730222478628337),
 (-0.8, -1.5510125944820812),
 (-0.7, -1.6071832453434687),
 (-0.6, -0.7530149734137868),
 (-0.5, -1.4185018340443283),
 (-0.4, -0.6055579756271128),
 (-0.3, -1.0067254915961406),
 (-0.2, -0.4382360549665138),
 (-0.1, -0.17621952751051906),
 (0.0, -0.12218090884626329),
 (0.1, 0.07428573423209717),
 (0.2, 0.4268795998864943),
 (0.3, 0.7254661223608084),
 (0.4, 0.04798697977420063),
 (0.5, 1.1578103735448106),
 (0.6, 1.5684111061340824),
 (0.7, 1.157745051031345),
 (0.8, 2.1744401978240675),
 (0.9, 1.6380001974121732),
 (1.0, 2.538951262545233)]

# %%
def plot_function(f,xmin,xmax,**kwargs):
    ts = np.linspace(xmin,xmax,1000)
    plt.plot(ts,[f(t) for t in ts],**kwargs)

# %%
plt.scatter([t[0] for t in test_data],[t[1] for t in test_data])
plt.ylabel("y", fontsize=16)
plt.xlabel("x", fontsize=16)
plot_function(lambda x: 2*x,-1,1,c='k')

# %%
# plt.plot([-2,2],[0,0],c='k')
plot_function(lambda x: abs(x),-2,2)

# %%
plot_function(lambda x: x*x, -2,2)

# %%
def sum_error(f,data):
    errors = [abs(f(x) - y) for (x,y) in data]
    return sum(errors)

def sum_squared_error(f,data):
    squared_errors = [(f(x) - y)**2 for (x,y) in data]
    return sum(squared_errors)

# %%
def f(x): 
    return 2*x

def g(x): 
    return 1-x

# %%
sum_error(g,test_data)
# Out:
# 38.47711311130152

# %%
sum_error(f,test_data)
# Out:
# 5.021727176394801

# %%
sum_squared_error(lambda x:1.5*x, test_data)
# Out:
# 4.828805747804679

# %%
def linear_cost(a,b):
    h = lambda x: a*x + b
    return sum_squared_error(h,test_data)

# %%
plot_function(lambda a:linear_cost(a,0),-2,3)

# %%
def scalar_field_heatmap(f,xmin,xmax,ymin,ymax,xsteps=100,ysteps=100):
    fig = plt.figure()
    fig.set_size_inches(7,7)

    fv = np.vectorize(f)

    X = np.linspace(xmin, xmax, xsteps)
    Y = np.linspace(ymin, ymax, ysteps)
    X, Y = np.meshgrid(X, Y)
    
    # https://stackoverflow.com/a/54088910/1704140
    z = fv(X,Y)
    
#     # x and y are bounds, so z should be the value *inside* those bounds.
#     # Therefore, remove the last value from the z array.
#     z = z[:-1, :-1]
#     z_min, z_max = -z.min(), z.max()

    fig, ax = plt.subplots()

    c = ax.pcolormesh(X,Y,z, cmap='plasma')
    # set the limits of the plot to the limits of the data
    ax.axis([X.min(), X.max(), Y.min(), Y.max()])

    fig.colorbar(c, ax=ax)

# %%
scalar_field_heatmap(linear_cost,-3,3,-3,3)

# %%
from vectors import length 
def secant_slope(f,xmin,xmax):
    return (f(xmax) - f(xmin)) / (xmax - xmin)

def approx_derivative(f,x,dx=1e-6):
    return secant_slope(f,x-dx,x+dx)

def approx_gradient(f,x0,y0,dx=1e-6):
    partial_x = approx_derivative(lambda x:f(x,y0),x0,dx=dx)
    partial_y = approx_derivative(lambda y:f(x0,y),y0,dx=dx)
    return (partial_x,partial_y)
    
def gradient_descent(f,xstart,ystart,tolerance=1e-6):
    x = xstart
    y = ystart
    grad = approx_gradient(f,x,y)
    while length(grad) > tolerance:
        x -= 0.01 * grad[0]
        y -= 0.01 * grad[1]
        grad = approx_gradient(f,x,y)
    return x,y

# %%
a,b = gradient_descent(linear_cost,-2,-2)

# %%
plt.scatter([t[0] for t in test_data],[t[1] for t in test_data])
plot_function(lambda x: a*x + b, -1, 1, c='k')

# %%
def draw_cost(h,points):
    xs = [t[0] for t in points]
    ys = [t[1] for t in points]
    plt.scatter(xs,ys)
    plot_function(h,min(xs),max(xs),c='k')
    for (x,y) in points:
        plt.plot([x,x],[y,h(x)],c='r')

# %%
a
# Out:
# 2.1037182061980104

# %%
draw_cost(lambda x: 2*x, test_data)
plt.ylabel("y", fontsize=16)
plt.xlabel("x", fontsize=16)
# Out:
# Text(0.5,0,'x')

# %%
draw_cost(lambda x: 1-x, test_data)
plt.ylabel("y", fontsize=16)
plt.xlabel("x", fontsize=16)
# Out:
# Text(0.5,0,'x')

# %%
sum_squared_error(f,test_data)
# Out:
# 2.105175107540148

# %%
sum_squared_error(g,test_data)
# Out:
# 97.1078879283203

# %%
def draw_square_cost(h,points):
    xs = [t[0] for t in points]
    ys = [t[1] for t in points]
    plt.scatter(xs,ys)
    plot_function(h,min(xs),max(xs),c='k')
    for (x,y) in points:
        e = abs(y - h(x))
        plt.plot([x,x],[y,h(x)],c='r')
        plt.fill([x,x,x+e,x+e],[h(x),y,y,h(x)],c='r',alpha=0.5)

# %%
draw_square_cost(lambda x: 2*x, test_data)
# plt.gcf().set_size_inches(7,7)
# plt.ylim(-2.5,3)
# plt.xlim(-2.5,3)
plt.ylabel("y", fontsize=16)
plt.xlabel("x", fontsize=16)
# Out:
# Text(0.5,0,'x')

# %%
draw_square_cost(lambda x: 3*x, test_data)
# plt.gcf().set_size_inches(7,7)
# plt.ylim(-2.5,3)
# plt.xlim(-2.5,3)
plt.ylabel("y", fontsize=16)
plt.xlabel("x", fontsize=16)
# Out:
# Text(0.5,0,'x')

# %%
draw_square_cost(lambda x: 0*x, test_data)

# %%
draw_square_cost(lambda x: 0.5*x, test_data)

# %%
draw_square_cost(lambda x: 0.8*x, test_data)

# %%
draw_square_cost(lambda x: x, test_data)

# %%
draw_square_cost(lambda x: 2*x, test_data)

# %%
plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.5)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)

plot_function(lambda x: 25000 - 0.2*x,0,125000,c='k')

# %%
def p1(x):
    return 25000 - 0.2 * x

def p2(x):
    return 25000 - 0.1 * x

def p3(x):
    return 22500 - 0.1 * x

# %%
sum_squared_error(p1, prius_mileage_price)
# Out:
# 124671842051.47993

# %%
sum_squared_error(p2, prius_mileage_price)
# Out:
# 65740457337.270004

# %%
sum_squared_error(p3, prius_mileage_price)
# Out:
# 46952467837.27001

# %%
plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.5)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)

plot_function(lambda x: 25000 - 0.10*x,0,250000,c='k')

# %%
plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.5)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)

plot_function(lambda x: 22500 - 0.10*x,0,225000,c='k')

# %%
def test_data_coefficient_cost(a):
    def f(x):
        return a * x
    return sum_squared_error(f,test_data)

# %%
plot_function(test_data_coefficient_cost, -5, 5)
plt.ylabel("cost", fontsize=16)
plt.xlabel("a", fontsize=16)
# Out:
# Text(0.5,0,'a')

# %%
# plot_function(test_data_coefficient_cost, -5, 5)
some_slopes = [-1,0,1,2,3]
plt.scatter(some_slopes,[test_data_coefficient_cost(a) for a in some_slopes])
plt.ylabel("cost", fontsize=16)
plt.xlabel("a", fontsize=16)
# Out:
# Text(0.5,0,'a')

# %%
plt.scatter([t[0] for t in test_data],[t[1] for t in test_data])
for a in some_slopes:
    plot_function(lambda x: a*x, -1, 1, c='k')
plt.ylabel("y", fontsize=16)
plt.xlabel("x", fontsize=16)
# Out:
# Text(0.5,0,'x')

# %%
def coefficient_cost(a,b):
    def p(x):
        return a * x + b
    return sum_squared_error(p,prius_mileage_price)

# %%
plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.5)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)

plot_function(lambda x: 25000 - 0.20*x,0,125000,c='k')
plot_function(lambda x: 5000 + 0.05*x,0,350000,c='k')

# %%
plt.scatter([-0.2, 0.05],[25000,5000])
plt.ylim(0,30000)
plt.xlim(-0.25,0.25)
plt.ylabel("b",fontsize=16)
plt.xlabel("a",fontsize=16)
# Out:
# Text(0.5,0,'a')

# %%
scalar_field_heatmap(coefficient_cost,-0.5,0.5,-50000,50000)
plt.ylabel("b",fontsize=16)
plt.xlabel("a",fontsize=16)
# Out:
# Text(0.5,0,'a')

# %%
coefficient_cost(0,0)/1000000000
# Out:
# 128.634669112

# %%
coefficient_cost(-0.1,20000)/1000000000
# Out:
# 38.364478337269986

# %%
def scaled_cost_function(c,d):
    return coefficient_cost(0.5*c,50000*d)/1e13

# %%
scalar_field_heatmap(scaled_cost_function,-1,1,-1,1)

# %%
c,d = gradient_descent(scaled_cost_function,0,0)

# %%
(c,d)
# Out:
# (-0.11194540619401672, 0.30462202112522635)

# %%
a = 0.5*c
b = 50000*d
(a,b)
# Out:
# (-0.05597270309700836, 15231.101056261317)

# %%
plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.5)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)



plot_function(lambda x: a*x + b,0,(-b/a),c='k')

# %%
0.5*scaled_a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-a248c2e668d6> in <module>()
# ----> 1 0.5*scaled_a
#
# NameError: name 'scaled_a' is not defined

# %%
50000*scaled_b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-0e4d6e0e344d> in <module>()
# ----> 1 50000*scaled_b
#
# NameError: name 'scaled_b' is not defined

# %%
def exp_coefficient_cost(q,r):
    def f(x):
        return q*exp(r*x)
    return sum_squared_error(f,prius_mileage_price)

# %%
scalar_field_heatmap(exp_coefficient_cost,0,30000,-1e-4,0)

# %%
def scaled_exp_coefficient_cost(s,t):
    return exp_coefficient_cost(30000*s,1e-4*t) / 1e11

scalar_field_heatmap(scaled_exp_coefficient_cost,0,1,-1,0)
plt.xlabel("s (scaled q)")
plt.ylabel("t (scaled r)")
# Out:
# Text(0,0.5,'t (scaled r)')

# %%
s,t = gradient_descent(scaled_exp_coefficient_cost,0,0)
(s,t)
# Out:
# (0.5377740185663437, -0.059517939364981745)

# %%
q,r = 30000*s,1e-4*t
(q,r)
# Out:
# (16133.220556990309, -5.951793936498175e-06)

# %%
1 - exp(r*10000)
# Out:
# 0.057781369364291235

# %%
plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.5)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)
plt.ylim(-5000,35000)
plt.xlim(0,375000)
plot_function(lambda x:0, -50000, 400000, c='gray')
plot_function(lambda x: q*exp(r*x),0,375000,c='k')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-bf5e36874298> in <module>()
# ----> 1 plot_mileage_price(priuses)
#       2 plt.ylim(-5000,35000)
#       3 plt.xlim(0,375000)
#       4 plot_function(lambda x:0, -50000, 400000, c='gray')
#       5 plot_function(lambda x: q*exp(r*x),0,375000,c='k')
#
# NameError: name 'plot_mileage_price' is not defined

# %%
plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.5)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)

plt.ylim(-5000,35000)
plt.xlim(0,375000)
plot_function(lambda x:0, -50000, 400000, c='gray')

plot_function(lambda x: a*x + b,0,375000,c='k')

# %%
sum_squared_error(lambda x: q*exp(r*x),prius_mileage_price)

# %%
sum_squared_error(lambda x: a*x+b, prius_mileage_price)

# %%
# def quadratic_coefficient_cost(A,B):
#     def f(x):
#         return A*x**2 + B*x
#     return sum_squared_error(f,prius_mileage_price)

# scalar_field_heatmap(quadratic_coefficient_cost,1e-5,1,-2,2)

# %%
1/r

# %%
1/10000

# %%
1/300000

# %%
1/exp(1)

# %%
exp(-1)

# %%
def test(x):
    return exp(-3*x)

# %%
test(1/3)

# %%
test(0)

# %%
from math import e
test(1/3), test(0)/e

# %%
test(2/3), test(1/3)/e

# %%
test(1), test(2/3)/e

# %%
test(1)

# %%
plot_function(lambda x:0.5+0.5*x,0,1)
plt.ylim(0,1.5)

# %%
def line(x):
    return 3*x-2

# %%
points = [(x,line(x)) for x in range(0,10)]

# %%
plt.scatter([p[0] for p in points], [p[1] for p in points])
plot_function(line,0,10)

# %%
sum_error(line,points)

# %%
sum_squared_error(line,points)

# %%
def test_data_linear_cost(a,b):
    def f(x):
        return a*x+b
    return sum_squared_error(f,test_data)

# %%
scalar_field_heatmap(test_data_linear_cost,-0,4,-2,2)
plt.ylabel("b",fontsize=16)
plt.xlabel("a",fontsize=16)

# %%
gradient_descent(test_data_linear_cost,1,1)

# %%
exp(-5.95e-6 * 10000)

# %%
def exponential_cost2(r):
    def f(x):
        return 25000 * exp(r*x)
    return sum_squared_error(f,prius_mileage_price)

# %%
plot_function(exponential_cost2,-1e-4,0)
plt.xlabel("r",fontsize=16)
plt.ylabel("cost",fontsize=16)

# %%
exponential_cost2(-1e-5)

# %%
exponential_cost2(-1.1e-5)

# %%
exponential_cost2(-1.09e-5) > exponential_cost2(-1.0e-5)

# %%
plt.scatter([p[3] for p in priuses if p[3] > 500],[p[4] for p in priuses if p[3] > 500],
#             c=[p[2] for p in priuses if p[3] > 500],
            alpha=0.5)
plt.ylabel("Price ($)",fontsize=16)
plt.xlabel("Odometer (mi)",fontsize=16)

q2 = 25000
r2 = -1.09e-5

plot_function(lambda x: q2*exp(r2*x),0,375000,c='k')
