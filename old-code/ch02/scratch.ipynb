# %%
# %load_ext autoreload
# %autoreload 2

# %%
from vector_drawing import *

draw(
    Points((1,1),(2,2),(3,3)),
    Polygon((1,1), (2,2), (1,2), fill=blue),
    Arrow((2,1)),
    Arrow((1,2), (2,1)),
    Segment((3,1), (1,5)),
    width = 6
)
