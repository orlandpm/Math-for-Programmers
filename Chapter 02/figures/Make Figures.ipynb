# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
from vector_drawing import *

# %% [markdown]
# ### Figure 2.1

# %%
dino_vectors = [(6,4), (3,1), (1,2), (-1,5), (-2,5), (-3,4), (-4,4),
    (-5,3), (-5,2), (-2,2), (-5,1), (-4,0), (-2,1), (-1,0), (0,-3),
    (-1,-4), (1,-4), (2,-3), (1,-2), (3,-1), (5,1)
]

draw(
    Points(*dino_vectors,color='C0'),
    Arrow((6,4),color='k'),
    grid=False,
    axes=False,
    save_as="2.01.svg"
)

# %% [markdown]
# ### Figure 2.2

# %%
draw(
    Points(*dino_vectors,color='C0'),
    Arrow((-2,5),color='k'),
    grid=False,
    axes=False,
    save_as="2.02.svg"
)

# %% [markdown]
# ### Figure 2.3

# %%
draw(
    Points(*dino_vectors,color='C0'),
    Polygon(*dino_vectors,color='C0'),
    grid=False,
    axes=False,
    save_as="2.03.svg"
)

# %% [markdown]
# ### Figure 2.4

# %%
draw(
    Points(*dino_vectors,color='C0'),
    Polygon(*dino_vectors,color='C0'),
    grid=False,
    save_as="2.04.svg"
)

# %% [markdown]
# ### Figure 2.5

# %%
draw(
    Points(*dino_vectors,color='C0'),
    Polygon(*dino_vectors,color='C0'),
    save_as="2.05.svg"
)

# %% [markdown]
# ### Figure 2.6

# %%
draw(
    Points((6,4),color='k'),
    Arrow((6,4),color='k'),
    save_as="2.06.svg"
)

# %% [markdown]
# ### Figure 2.7

# %%
draw(
    Points(*dino_vectors),
    save_as="2.07.svg"
)

# %% [markdown]
# ### Figure 2.8

# %%
draw(
    Points(*dino_vectors),
    Segment((6,4),(3,1)),
    save_as="2.08.svg"
)

# %% [markdown]
# ### Figure 2.9

# %%
draw(
    Points(*dino_vectors),
    Polygon(*dino_vectors),
    save_as="2.09.svg"
)

# %% [markdown]
# ### Figure 2.10

# %%
draw(
    Arrow((-1,1)),
    Arrow((3,4),color='k'),
    Arrow((4,3),color='purple'),
    Arrow((3,4),(4,3)),
    save_as="2.10.svg"
)

# %% [markdown]
# ### Figure 2.13

# %%
def add(v1,v2):
    return (v1[0] + v2[0], v1[1] + v2[1])
dino_vectors2 = [add((-1.5,-2.5), v) for v in dino_vectors]
draw(
    Points(*dino_vectors, color=blue),
    Polygon(*dino_vectors, color=blue),
    Points(*dino_vectors2, color=red),
    Polygon(*dino_vectors2, color=red),
    save_as="2.13-left.svg"
)

# %%
arrows = [Arrow(tip,tail,color=black) for (tip,tail) in
         zip(dino_vectors2, dino_vectors)]
draw(
    Points(*dino_vectors, color=blue),
    Polygon(*dino_vectors, color=blue),
    Points(*dino_vectors2, color=red),
    Polygon(*dino_vectors2, color=red),
    *arrows,
    save_as="2.13-right.svg"
)

# %% [markdown]
# ### Figure 2.14

# %%
draw(
    Arrow((4,0),color='blue'),
    Arrow((4,3),(4,0),color='red'),
    Arrow((4,3),color='purple'),
    save_as="2.14.svg"
)

# %% [markdown]
# ### Figure 2.15

# %%
draw(
    Arrow((4,0),color='blue'),
    Arrow((4,3),(4,0),color='red'),
    Arrow((4,3),color='purple'),
    save_as="2.15.svg"
)

# %% [markdown]
# ### Figure 2.16

# %%
arrows = [
    Arrow((2*x+2,x+1),(2*x,x),color='C0') 
    for x in range(5)
]

# %%
draw(*arrows,save_as='2.16.svg')

# %% [markdown]
# ### Figure 2.18

# %%
draw(
    Arrow((6,4),color='purple'),
    Arrow((9,6),color='purple'),
    Arrow((6,4),(6,0),color='blue'),
    Arrow((9,6),(9,0),color='blue'),
    Arrow((6,0),color='red'),
    Arrow((9,0),color='red'),
    Segment((0,0),(9,0),color='red'),
    save_as='2.18.svg'
)

# %% [markdown]
# ### Figure 2.19

# %%
draw(
    Arrow((6,4),color='C0'),
    Arrow((-3,-2),color='C1'),
    save_as='2.19.svg'
)

# %% [markdown]
# ### Figure 2.20

# %%
draw(
    Arrow((4,-3),color='C0'),
    Arrow((-4,3),color='C1'),
    save_as='2.20.svg'
)

# %% [markdown]
# ### Figure 2.21

# %%
draw(
    Arrow((2,2),color='C0'),
    Arrow((-1,3),color='C0'),
    Arrow((-3,1),color='red'),
    Arrow((-1,3),(2,2),color='red'),
    save_as='2.21.svg'
)

# %%
draw(
    Points((2,2),(-1,3),color='k'),
    Segment((2,2),(-1,3),color='red'),
    save_as='2.22.svg'
)

# %% [markdown]
# ### Figure 2.23

# %%
draw(
    Points((2,2),(-1,3),(3,5),(3,-1),(-1,1),color='k'),
    Segment((2,2),(-1,3),color='red'),
    Segment((2,2),(3,5),color='purple'),
    Segment((2,2),(3,-1),color='purple'),
    Segment((2,2),(-1,1),color='purple'),
    save_as='2.23.svg'
)

# %% [markdown]
# ### Figure 2.24

# %%
draw(
    Points((4,3),color='k'),
    Segment((0,0),(4,3),color='red'),
    save_as='2.24.svg'
)

# %% [markdown]
# ### Figure 2.25

# %%
draw(
    Arrow((-1.34,2.68),(0,0),color='red'),
    Points((-4,3),(2,3),color=(0,0,0,0)),
    save_as='2.25.svg'
)

# %% [markdown]
# ### Figure 2.26

# %%
draw(
    Arrow((-1.34,0),(0,0),color='C0'),
    Segment((-1.34,0),(0,0),color='C0'),
    Arrow((-1.34,2.68),(-1.34,0),color='C0'),
    Points((-4,3),(2,3),color=(0,0,0,0)),
    save_as='2.26.svg'
)

# %% [markdown]
# ### Figure 2.27

# %%
objs = []
for vx,vy in [(-1,2),(-1.34,2.68),(-3,6)]:
    objs.append(Arrow((vx,0),(0,0),color='C0'))
    objs.append(Segment((vx,0),(0,0),color='C0'))
    objs.append(Arrow((vx,vy),(vx,0),color='C0'))
    
draw(
    Points((-4,3),(2,3),color=(0,0,0,0)),
    *objs,
    save_as='2.27.svg'
)

# %% [markdown]
# ### Figure 2.28

# %%
draw(
    Points((1,1),(-1,-0.36)),
    save_as='2.28.svg'
)

# %% [markdown]
# ### Figure 2.30

# %%
draw(
    Points((4,3),color='k'),
    Segment((0,0),(4,3),color='red'),
    save_as='2.30.svg'
)

# %% [markdown]
# ### Figure 2.33

# %%
draw(
    Points((-2,3),color='k'),
    Arrow((-2,3),color='k'),
    Points((-3,3),(3,3),color=(0,0,0,0)),
    save_as='2.33.svg'
)

# %% [markdown]
# ### Figure 2.34

# %%
from math import cos,sin,pi
draw(
    Points((-2,3),color='k'),
    Arrow((-2,3),color='k'),
    Arrow((3*cos(56.3*pi/180),3*sin(56.3*pi/180)),color='C0'),
    Points((-3,3),(3,3),color=(0,0,0,0)),
    save_as='2.34.svg'
)

# %% [markdown]
# ### Figure 2.35

# %%
objs = []
for r,theta in [(1,1),(1,2),(1,3)]:
    (x,y) = (r*cos(theta),r*sin(theta))
    objs.append(Points((x,y),color='k'))
    objs.append(Arrow((x,y),color='C0'))
    
draw(
    *objs,
#     Points((-3,3),(3,3),color=(0,0,0,0)),
    save_as='2.35.svg'
)

# %% [markdown]
# ### Figure 2.36

# %%
from vectors import to_polar, to_cartesian

rotation_angle = pi/4
dino_polar = [to_polar(v) for v in dino_vectors]
dino_rotated_polar = [(l,angle + rotation_angle) for l,angle in dino_polar]
dino_rotated = [to_cartesian(p) for p in dino_rotated_polar]
draw(
    Polygon(*dino_vectors, color=gray),
    Polygon(*dino_rotated, color=red),
    save_as='2.36.svg'
)

# %% [markdown]
# ### Figure 2.37

# %%
from vectors import translate, rotate
new_dino = translate((8,8), rotate(5 * pi/3, dino_vectors))

# %% [markdown]
# draw(
#     Polygon(*dino_vectors, color=gray),
#     Polygon(*new_dino, color=red),
#     save_as='2.37.svg'
# )

# %% [markdown]
# # Misc Figures

# %%
from math import sqrt, pi

w = (sqrt(2),sqrt(3))
w_scaled = (pi * sqrt(2), pi * sqrt(3))

draw(
    Arrow(w_scaled, color=red),
    Arrow(w, color=black),
    save_as='original_and_scaled_vectors.svg'
)

# %%
from random import uniform
from vectors import scale
u = (-1,1)
v = (1,1)
def random_r():
    return uniform(-3,3)
def random_s(): 
    return uniform(-1,1)
possibilities = [add(scale(random_r(), u), scale(random_s(), v)) 
                 for i in range(0,500)]
draw(
    Points(*possibilities),
    save_as='lots_of_points.svg'
)

# %%
draw(
    Points(*[(x,x**2) for x in range(-10,11)]),
    grid=(1,10),
    nice_aspect_ratio=False, # don't require x scale to match y scale
    save_as="y-equals-x-squared.svg"
)

# %%
draw(
    Arrow((2,-2),color='gray'),
    Points((2,-2),color='C0'),
    Points((1,1),(3,1),(3,-3),(-1,-3),color=(0,0,0,0)),
    save_as="point_and_arrow.svg"
)

# %%
from math import tan
draw(
    Segment((0,0),(13,13*tan(22*pi/180)),color='C3'),
    save_as='22_degrees_a.svg'
)

# %%
draw(
    Segment((0,0),(13,13*tan(22*pi/180)),color='C3'),
    Arrow((10,0),(0,0),color='C0'),
    Arrow((10,10 * tan(22*pi/180)),(10,0),color='C0'),
    Segment((10,0),(0,0),color='C0'),
    Segment((10,10 * tan(22*pi/180)),(10,0),color='C0'),
    Points((10,10*tan(22*pi/180)),color='C0'),
    save_as='22_degrees_b.svg'
)

# %%
polar_coords = [(cos(x*pi/100.0), 2*pi*x/1000.0) for x in range(0,1000)]
vectors = [to_cartesian(p) for p in polar_coords]
draw(Polygon(*vectors, color=green),save_as='polar_flower.svg')

# %%
def regular_polygon(n):
    return [to_cartesian((1, 2*pi*k/n)) for k in range(0,n)]

draw(
    Polygon(*regular_polygon(7),color='C0'),
    Points(*regular_polygon(7),color='C0'),
    save_as="heptagon.svg"
)

# %%
t_dino = translate((8,8), dino_vectors)
r_t_dino = rotate(5 * pi/3, translate((8,8), dino_vectors))
draw(
    Polygon(*dino_vectors,color='C0'),
    Polygon(*t_dino,color='C3'),
    Polygon(*r_t_dino,color='C4'),
    Arrow((8,8),color='k'),
    Points((8,8),color='k'),
    Points(*rotate(5 * pi/3,[(8,8)]),color='k')
)
